# %% [markdown]
# # Esercizi 2.*

# %% [markdown]
# # 2.1: Integrali

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

y, err = np.loadtxt('data/UnifInt.dat', usecols=(0,1), delimiter=' ', unpack=True)
x      = np.arange(y.size)*100

plt.errorbar(x,y-1,err)
plt.grid(True)
plt.xlabel('#throws')
plt.ylabel('Integral - 1')
plt.title("pdf uniforme")

plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

y, err = np.loadtxt('data/ImpInt.dat', usecols=(0,1), delimiter=' ', unpack=True)
x      = np.arange(y.size)*100

plt.errorbar(x,y-1,err)
plt.grid(True)
plt.xlabel('#throws')
plt.ylabel('Integral - 1')
plt.title("pdf uniforme")

plt.show()

# %% [markdown]
# Un pelo meno compatibile, ma comunque non male: $\sigma_{unif} = 5 \sigma_{impsampl}$

# %% [markdown]
# # 2.2: Random Walks

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

def f (x,k):
    return k*(x**0.5)


y, err = np.loadtxt("data/discreteRW.dat", usecols=(0,1), delimiter=' ', unpack=True)
x      = np.arange(y.size)

plt.errorbar(x,y,err)
plt.grid(True)
plt.xlabel('passi')
plt.ylabel('sqrt(<|r|^2>)')
plt.title('Random Walk su reticolo discreto - a=1')

p_opt, p_cov = curve_fit(f, x, y)
y_fit = f(x,p_opt[0])
plt.plot(x,y_fit,'r--') # plotting fitted function

print( ' --- Random Walk over a discrete lattice --- ')
print('fit with k*sqrt(x): k = '+str(p_opt))
print('confidence over k : +- '+str(np.sqrt(np.diagonal(p_cov))))

plt.figure()

y,err = np.loadtxt("data/continuousRW.dat", usecols=(0,1), delimiter=' ', unpack=True)

plt.errorbar(x,y,err)
plt.grid(True)
plt.xlabel('passi')
plt.ylabel('sqrt(<|r|^2>)')
plt.title('Random Walk su reticolo continuo - a=1')

p_opt, p_cov = curve_fit(f, x, y)
y_fit = f(x,p_opt[0])
plt.plot(x,y_fit,'r--') # plotting fitted function

print( ' --- Random Walk in a continuum space --- ')
print('fit with k*sqrt(x): k = '+str(p_opt))
print('confidence over k : +- '+str(np.sqrt(np.diagonal(p_cov))))

plt.show()
# Out:
#  --- Random Walk over a discrete lattice ---
# fit with k*sqrt(x): k = [1.00342455]
# confidence over k : +- [0.00017971]
#  --- Random Walk in a continuum space ---
# fit with k*sqrt(x): k = [1.0010321]
# confidence over k : +- [0.00027354]

# %% [markdown]
# sarebbe carino avere un confidence level quando si fitta
